# %% [markdown]
# <a href="https://colab.research.google.com/github/DIVYA14797/pandas/blob/main/Pandas_Advanced_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. List any five functions of the pandas library with execution .

# %% [markdown]
# i)  read_csv(): This function is used to read data from a CSV file into a DataFrame.

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')

# %% [markdown]
# ii) head(): Returns the first n rows of the DataFrame. By default, it returns the first 5 rows.

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# iii)  describe(): Generates descriptive statistics of the DataFrame, such as count, mean, standard deviation, etc.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# iv)  groupby(): Groups the DataFrame using a mapper or by a Series of columns.

# %%
df.groupby('density')

# %% [markdown]
# v)  plot(): This function is used to plot data. It requires matplotlib to be installed.

# %%
import matplotlib.pyplot as plt
df['density'].plot()
plt.show()

# %% [markdown]
# 2. Given a pandas DataFrame df with columns 'A','B', and ,'C' , write a python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row .

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
import pandas as pd

def reindex_df(df):
    new_index = pd.Index(range(1, len(df) * 2, 2))
    df_reindexed = df.set_index(new_index)
    return df_reindexed

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df_reindexed = reindex_df(df)

# %%
df_reindexed
# Out:
#    A  B  C
# 1  1  4  7
# 3  2  5  8
# 5  3  6  9

# %% [markdown]
# 3. You have a pandas DataFrame df with a column named 'Values' . Write a python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column . The function should print the sum to the console .
#
# For example , if the 'Values' column of df contains the values[10,20,30,40,50] , your function should calculate and print the sum of the first three values ,which is 60 .

# %%
import pandas as pd

def calculate_sum_of_first_three(df):
    sum_of_first_three = df['Values'].iloc[:3].sum()
    print("Sum of the first three values:", sum_of_first_three)
df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]})
calculate_sum_of_first_three(df)
# Out:
# Sum of the first three values: 60

# %% [markdown]
# 4. Given a pandas DataFrame df with a column 'Text' , write a python function to create a new column 'word_count'  that contains the number of words in each row of the 'Text' column .

# %%
import pandas as pd

def add_word_count_column(df):
    def count_words(text):
        return len(text.split())

    df['word_count'] = df['Text'].apply(count_words)
    return df

df = pd.DataFrame({'Text': ["Hello world", "This is a sentence", "Python is awesome"]})
df = add_word_count_column(df)
print(df)
# Out:
#                  Text  word_count
# 0         Hello world           2
# 1  This is a sentence           4
# 2   Python is awesome           3

# %% [markdown]
# 5. How are DataFrame.size() and DataFrame.shape() different ?

# %% [markdown]
# 1. DataFrame.size:
#
# * DataFrame.size returns the total number of elements in the DataFrame, which is calculated by multiplying the number of rows by the number of columns.
# * It gives you the total count of cells in the DataFrame.
#
# 2. DataFrame.shape:
#
# * DataFrame.shape returns a tuple representing the dimensions of the DataFrame, where the first element is the number of rows and the second element is the number of columns.
# * It gives you the structure of the DataFrame in terms of rows and columns.

# %% [markdown]
# 6. Which function of pandas do we use to read an excel file ?

# %% [markdown]
# To read an Excel file into a pandas DataFrame, you use the 'read_excel()' function.

# %% [markdown]
# 7. You have a pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com' . Write a pyton function that creates a new column 'Username' in df that contains only the username part of each email address .
#
# The username is the part of the email address that appear before the '@' symbol . For example , if the email address is 'john.doe@example.com' , the 'Username' column should contain 'john.doe' . Your function should extract the username from each email address and store it in the new 'Username' column .

# %%
import pandas as pd

def extract_username(df):
    df['Username'] = df['Email'].apply(lambda x: x.split('@')[0])
    return df

df = pd.DataFrame({'Email': ["john.doe@example.com", "jane.smith@example.com"]})
df = extract_username(df)
print(df)
# Out:
#                     Email    Username
# 0    john.doe@example.com    john.doe
# 1  jane.smith@example.com  jane.smith

# %% [markdown]
# 8. You have a pandas DataFrame df with columns 'A' ,'B' , and 'C' . Write a python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10 . The function should return a new DataFrame that contains only the selected rows .

# %%
import pandas as pd

def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return selected_rows

df = pd.DataFrame({'A': [3, 8, 6, 2, 9], 'B': [5, 2, 9, 3, 1], 'C': [1, 7, 4, 5, 2]})
selected_df = select_rows(df)
print(selected_df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# 9. Given  a pandas DataFrame df with a column 'Values' , write a python function to calculate the mean , median and standard deviation of the values in the 'Values' column .

# %%
import pandas as pd

def calculate_stats(df):
    mean_value = df['Values'].mean()
    median_value = df['Values'].median()
    std_deviation = df['Values'].std()

    return mean_value, median_value, std_deviation

df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]})
mean, median, std_dev = calculate_stats(df)
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 15.811388300841896

# %% [markdown]
# 10. Given a pandas DataFrame df with column 'Sales' and a column 'Date' ,write a python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DtaFrame . The moving average should be calculated using a window of size 7 and should include the current day .

# %%
import pandas as pd

def add_moving_average_column(df):
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values(by='Date')

    # Calculate moving average using a window of size 7
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()

    return df

df = pd.DataFrame({'Date': ['2024-04-01', '2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05'],
                    'Sales': [10, 20, 30, 40, 50]})
df = add_moving_average_column(df)
print(df)
# Out:
#         Date  Sales  MovingAverage
# 0 2024-04-01     10           10.0
# 1 2024-04-02     20           15.0
# 2 2024-04-03     30           20.0
# 3 2024-04-04     40           25.0
# 4 2024-04-05     50           30.0

# %% [markdown]
# 11. You have a pandas DataFrame df with a column 'Date' . Write a python function that creates a new column 'Weekday' in the DataFrame . The 'Weekday' column should contain the weekday name (e.g. Monday , Tuesday) corresponding to each date in the 'Date' column .

# %%
import pandas as pd

def add_weekday_column(df):
    df['Date'] = pd.to_datetime(df['Date'])

    # Extract weekday name from 'Date' column and store it in a new column 'Weekday'
    df['Weekday'] = df['Date'].dt.strftime('%A')

    return df

df = pd.DataFrame({'Date': ['2024-04-01', '2024-04-02', '2024-04-03', '2024-04-04', '2024-04-05']})
df = add_weekday_column(df)
print(df)
# Out:
#         Date    Weekday
# 0 2024-04-01     Monday
# 1 2024-04-02    Tuesday
# 2 2024-04-03  Wednesday
# 3 2024-04-04   Thursday
# 4 2024-04-05     Friday

# %% [markdown]
# 12. Given a pandas DataFrame df with a column 'Date' that contains timestamps , write a python function to select all rows where the date is between '2023-01-01' and '2023-01-31' .

# %%
import pandas as pd

def select_rows_between_dates(df):
    # Convert 'Date' column to datetime if it's not already
    df['Date'] = pd.to_datetime(df['Date'])

    # Define start and end dates of the range
    start_date = pd.Timestamp('2023-01-01')
    end_date = pd.Timestamp('2023-01-31')

    # Use boolean indexing to select rows within the specified date range
    selected_rows = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

    return selected_rows

df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-15', '2023-02-01', '2023-01-25']})
df = select_rows_between_dates(df)
print(df)
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-15
# 3 2023-01-25

# %% [markdown]
# 13. To use the basic functions of pandas , what is the first and foremost necessary library that needs to be imported ?

# %% [markdown]
# The first and foremost necessary library that needs to be imported to use the basic functions of pandas is 'pandas' itself.

# %%
import pandas as pd
